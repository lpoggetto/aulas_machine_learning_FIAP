# %% [markdown]
# <a href="https://colab.research.google.com/github/lpoggetto/aulas_machine_learning_FIAP/blob/main/aula_1_ML_FIAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/quant/master/notas%20(2).csv')

# %%
df.head()
# Out:
#   Curso Alunos  AP1   AP2   AP3  Nota Conceito
# 0   ADM   João  9.0   8.0   9.0   8.6        B
# 1   ADM  Maria  6.0   4.0  10.0   6.0        D
# 2   DIR   José  4.0   3.0   4.0   3.6        F
# 3   ADM  Pedro  8.0  10.0   7.0   8.6        B
# 4   ECO  Paulo  7.5   8.0   9.5   8.1        B

# %%
df[['Curso' , 'Alunos', 'Nota']]
# Out:
#    Curso   Alunos  Nota
# 0    ADM     João   8.6
# 1    ADM    Maria   6.0
# 2    DIR     José   3.6
# 3    ADM    Pedro   8.6
# 4    ECO    Paulo   8.1
# 5    DIR   Esther   5.4
# 6    ADM  Gabriel   7.2
# 7    DIR   Rafael   8.9
# 8    ECO     Davi   7.8
# 9    DIR   Silvio   9.7
# 10   ADM    Sofia   7.2
# 11   ADM   Raquel   4.2

# %%
df['Nota'].loc[df['Nota'] > 8]
# Out:
# 0    8.6
# 3    8.6
# 4    8.1
# 7    8.9
# 9    9.7
# Name: Nota, dtype: float64

# %%
df.groupby('Curso')['Nota'].mean()
# Out:
# Curso
# ADM    6.966667
# DIR    6.900000
# ECO    7.950000
# Name: Nota, dtype: float64
