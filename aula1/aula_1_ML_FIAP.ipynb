# %% [markdown]
# <a href="https://colab.research.google.com/github/lpoggetto/aulas_machine_learning_FIAP/blob/main/aula_1_ML_FIAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/quant/master/notas%20(2).csv')

# %%
df.head()
# Out:
#   Curso Alunos  AP1   AP2   AP3  Nota Conceito
# 0   ADM   João  9.0   8.0   9.0   8.6        B
# 1   ADM  Maria  6.0   4.0  10.0   6.0        D
# 2   DIR   José  4.0   3.0   4.0   3.6        F
# 3   ADM  Pedro  8.0  10.0   7.0   8.6        B
# 4   ECO  Paulo  7.5   8.0   9.5   8.1        B

# %%
df[['Curso' , 'Alunos', 'Nota']]
# Out:
#    Curso   Alunos  Nota
# 0    ADM     João   8.6
# 1    ADM    Maria   6.0
# 2    DIR     José   3.6
# 3    ADM    Pedro   8.6
# 4    ECO    Paulo   8.1
# 5    DIR   Esther   5.4
# 6    ADM  Gabriel   7.2
# 7    DIR   Rafael   8.9
# 8    ECO     Davi   7.8
# 9    DIR   Silvio   9.7
# 10   ADM    Sofia   7.2
# 11   ADM   Raquel   4.2

# %%
df['Nota'].loc[df['Nota'] > 8]
# Out:
# 0    8.6
# 3    8.6
# 4    8.1
# 7    8.9
# 9    9.7
# Name: Nota, dtype: float64

# %%
df.groupby('Curso')['Nota'].mean()
# Out:
# Curso
# ADM    6.966667
# DIR    6.900000
# ECO    7.950000
# Name: Nota, dtype: float64

# %%
media_por_curso = df.groupby('Curso')['Nota'].mean()
media_por_curso.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Curso'>

# %%
qtd_por_curso = df.groupby('Curso').count()['Alunos']
qtd_por_curso
# Out:
# Curso
# ADM    6
# DIR    4
# ECO    2
# Name: Alunos, dtype: int64

# %%
qtd_por_curso.plot(kind = 'pie')
# Out:
# <Axes: ylabel='Alunos'>

# %%
df.head()
# Out:
#   Curso Alunos  AP1   AP2   AP3  Nota Conceito
# 0   ADM   João  9.0   8.0   9.0   8.6        B
# 1   ADM  Maria  6.0   4.0  10.0   6.0        D
# 2   DIR   José  4.0   3.0   4.0   3.6        F
# 3   ADM  Pedro  8.0  10.0   7.0   8.6        B
# 4   ECO  Paulo  7.5   8.0   9.5   8.1        B

# %%
cov = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/quant/master/covid_br%20-%20ok.csv')

# %%
cov
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 269            NaN             Vietnam  14.058324  108.277199        0
# 270            NaN  West Bank and Gaza  31.952200   35.233200        0
# 271            NaN               Yemen  15.552727   48.516388        0
# 272            NaN              Zambia -13.133897   27.849332        0
# 273            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/11/21  4/12/21  \
# ...

# %% [markdown]
# ### Atividade 1 - Estatística
#
# EXERCÍCIO: Estatística
#
# * Defina categorias de altura: muito baixo, baixo, médio, alto, muito alto
# * Apresente o histograma
# * Calcule os quartis
# * Apresente o boxplot

# %%
dados_atividade = pd.read_csv('https://raw.githubusercontent.com/lcbjrrr/data/main/altura%20-%20masc.csv')

# %%
dados_atividade.head()
# Out:
#    altura_masc
# 0          187
# 1          157
# 2          172
# 3          181
# 4          179

# %%
dados_atividade['altura_cat'] = pd.qcut(dados_atividade['altura_masc'], q=5, labels=['muito baixo', 'baixo', 'médio', 'alto', 'muito alto'])

# %%
# Dados distribuidos
dados_atividade.head()
# Out:
#    altura_masc   altura_cat
# 0          187   muito alto
# 1          157  muito baixo
# 2          172        baixo
# 3          181         alto
# 4          179         alto

# %%
sns.displot(dados_atividade['altura_masc'])
plt.title('Distribuição de altura')
plt.show()

# %%
# Calculando os quartis e plotando
#dados_atividade['altura_masc'].describe()
dados_atividade['altura_masc'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    163.5
# 0.50    175.0
# 0.75    179.5
# Name: altura_masc, dtype: float64

# %%
sns.boxplot(x = dados_atividade['altura_masc'])
plt.title('Boxplot - Altura')
plt.show()
